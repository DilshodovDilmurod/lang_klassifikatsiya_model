# %%
#https://huggingface.co/datasets/MD1998/pre_training_texts_english
#https://huggingface.co/datasets/elmurod1202/uzbek-sentiment-analysis/tree/main
#https://huggingface.co/datasets/Jeoor/russian_dataset?row=97

# %%
import pandas as pd

# %%
data_en= pd.read_json('/content/texts.json')
data_ru=pd.read_csv('/content/train.csv')
data_uz=pd.read_fwf('/content/UZ_positive.txt', index_cols=0)
data_uz1=pd.read_fwf('/content/negative10kUZ.txt', index_cols=0)
data_uz2=pd.read_fwf('/content/positive10kUZ.txt', index_cols=0)

# %% [markdown]
# # UZB text

# %%
data_uz.columns
# Out:
# Index(['Super', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5'],
#       dtype='object')

# %%
data_uz['lang']='uz'

# %%
data_uz.head()
# Out:
#                                                 text lang
# 0                                           Axa zo'r   uz
# 1  Barakalla! Yaxshi tashkil etilgan va ko'rsatma...   uz
# 2  Ajoyib application Gap bolishi mumkinmas. Juda...   uz
# 3                         Juda zo'r Ovqat jonu dilim   uz
# 4                        Juda foydali dastur. Rahmat   uz

# %%
data_uz.drop(columns=['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
       'Unnamed: 5'], axis=1, inplace=True)

# %%
data_uz.rename(columns={'Super':"text"}, inplace=True)

# %%
data_uz.shape
# Out:
# (3041, 2)

# %%
data_uz1.columns
# Out:
# Index(['Yoki men hech narsa qila olmadim', 'Unnamed: 1', 'Unnamed: 2'], dtype='object')

# %%
data_uz1['lang']='uz'

# %%
data_uz1.drop(columns=['Unnamed: 1', 'Unnamed: 2'], inplace=True)

# %%
data_uz1.rename(columns={'Yoki men hech narsa qila olmadim':'text'}, inplace=True)

# %%
data_uz1.head()
# Out:
#                                                 text lang
# 0  STUPID QO'ShIMChA QO'ShIMChA QO'ShIMChA QO'ShI...   uz
# 1  WTF Batafsil ma'lumot kerak. 1. Quyosh 900 dar...   uz
# 2  Ushbu o'yinni yaxshi ko'raman. Lekin men to'sa...   uz
# 3           Endi Markni n rasmlarini yubora olmaysiz   uz
# 4  Hech qanday onlayn kiyinish Wad sharmandalik, ...   uz

# %%
data_uz1.shape
# Out:
# (9624, 2)

# %%
data_uz2.head()
# Out:
#                                  Uni yaxshi ko'raman Unnamed: 1
# 0  Bunga qo'shimcha qilish kerak bo'lgan yuklab o...        NaN
# 1                                Bepul bepul qo'shiq        NaN
# 2  Kyla saka Ushbu o'yinlarni o'ynashni yaxshi ko...        NaN
# 3  Juda ham ajoyib. Bugungi kunga qadar men 36 ta...        NaN
# 4  Haqiqatan ham yaxshi ishlar mening eski HTC is...        NaN

# %%
data_uz2.drop(columns=['Unnamed: 1'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-596bd91085ec> in <cell line: 0>()
# ----> 1 data_uz2.drop(columns=['Unnamed: 1'], inplace=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
data_uz2['lang']='uz'

# %%
data_uz2.rename(columns={"Uni yaxshi ko'raman":'text'}, inplace=True)

# %%
data_uz2.head()
# Out:
#                                                 text lang
# 0  Bunga qo'shimcha qilish kerak bo'lgan yuklab o...   uz
# 1                                Bepul bepul qo'shiq   uz
# 2  Kyla saka Ushbu o'yinlarni o'ynashni yaxshi ko...   uz
# 3  Juda ham ajoyib. Bugungi kunga qadar men 36 ta...   uz
# 4  Haqiqatan ham yaxshi ishlar mening eski HTC is...   uz

# %%
data_uz2.shape
# Out:
# (8850, 2)

# %%
df = pd.concat([data_uz, data_uz1])

# %%
data_uz = pd.concat([df, data_uz2])

# %%
data_uz.shape
# Out:
# (21515, 2)

# %%
data_uz.reset_index(drop=True, inplace=True)

# %%
data_uz.index
# Out:
# RangeIndex(start=0, stop=21515, step=1)

# %%
data_uz.columns
# Out:
# Index(['text', 'lang'], dtype='object')

# %%
data_uz.drop(columns=['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
       'Unnamed: 5', 'text', 'lang', "Uni yaxshi ko'raman"], inplace=True)

# %%
data_uz['lang']='uz'

# %%
data_uz.rename(columns={'Super':'text'})
# Out:
#                                                     text lang
# 0                                               Axa zo'r   uz
# 1      Barakalla! Yaxshi tashkil etilgan va ko'rsatma...   uz
# 2      Ajoyib application Gap bolishi mumkinmas. Juda...   uz
# 3                             Juda zo'r Ovqat jonu dilim   uz
# 4                            Juda foydali dastur. Rahmat   uz
# ...                                                  ...  ...
# 21510                                                NaN   uz
# 21511                                                NaN   uz
# 21512                                                NaN   uz
# 21513                                                NaN   uz
# 21514                                                NaN   uz
#
# [21515 rows x 2 columns]

# %% [markdown]
# # RU text

# %%
data_ru.head()
# Out:
#    Id                                               Text Class
# 0   0  Обустройство тротуаров, мостовых (в том числе ...     H
# 1   1  Въ издержкахъ же оныхъ вы имете присылать счет...     H
# 2   2                      Положи это туда, откуда взял.     H
# 3   3  Минстрой обозначил способы снижения энергоемко...     M
# 4   4  В конце 1873 года военный суд вынес решение по...     M

# %%
data_ru['lang']='ru'

# %%
data_ru.drop(columns=['Id'], inplace=True)

# %%
data_ru.drop(columns=['Class'], inplace=True)

# %%
data_ru.head()
# Out:
#                                                 Text lang
# 0  Обустройство тротуаров, мостовых (в том числе ...   ru
# 1  Въ издержкахъ же оныхъ вы имете присылать счет...   ru
# 2                      Положи это туда, откуда взял.   ru
# 3  Минстрой обозначил способы снижения энергоемко...   ru
# 4  В конце 1873 года военный суд вынес решение по...   ru

# %%
data_ru.shape
# Out:
# (21515, 2)

# %% [markdown]
# ENG text

# %%
data_ru=data_ru.head(21515)

# %%
data_en['lang']='en'

# %%
data_en.head(10)
# Out:
#                                                 text lang
# 0                                betty where are you   en
# 1                                    i'm right here    en
# 2                              dear betty guess what   en
# 3                              you are getting a dog   en
# 4                                             huh no   en
# 5                             you're getting married   en
# 6                                            what no   en
# 7                                 okay i can't guess   en
# 8                                       look at this   en
# 9  it's a check for 100 it's my prize from a writ...   en

# %%
data_en=data_en.head(21515)

# %%
data_en.shape
# Out:
# (21515, 1)

# %%
data_en.index
# Out:
# RangeIndex(start=0, stop=21515, step=1)

# %%
data_en.to_csv('data_en', index=False)

# %%
data_uz.shape
# Out:
# (21515, 2)

# %%
data_ru.shape
# Out:
# (21515, 3)

# %%
data_ru.index
# Out:
# RangeIndex(start=0, stop=21515, step=1)

# %%
data_ru.to_csv('data_ru', index=False)

# %%
def detect_language(text):
    text_tfidf = vectorizer.transform([text])
    lang = model.predict(text_tfidf)[0]
    return lang

# Example usage:
new_text = "hello"
predicted_language = detect_language(new_text)
print(f"Detected language: {predicted_language}")
# Out:
# Detected language: ru

# %%
import pandas as pd

# %%
data_en=pd.read_csv('/content/data_en')
data_uz=pd.read_csv('/content/data_uz')
data_ru=pd.read_csv('/content/data_ru')

# %%
data_ru.rename(columns={'Text':'text'}, inplace=True)

# %%
en_ru=pd.concat([data_en, data_ru])

# %%
data=pd.concat([en_ru, data_uz])

# %%
data.reset_index(drop=True, inplace=True)

# %%
data.to_csv('lang_data', index=False)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64534 entries, 0 to 64544
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    64534 non-null  object
#  1   lang    64534 non-null  object
# dtypes: object(2)
# memory usage: 1.5+ MB

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(data['text'], data['lang'], test_size=0.2, random_state=42)


from sklearn.feature_extraction.text import TfidfVectorizer

# Convert text data into TF-IDF features
vectorizer = TfidfVectorizer()
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, accuracy_score

# Train the model
model = MultinomialNB()
model.fit(X_train_tfidf, y_train)

# Predict on the test set
y_pred = model.predict(X_test_tfidf)


# Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.993181994266677
# Classification Report:
#                precision    recall  f1-score   support
#
#           en       0.98      1.00      0.99      4249
#           ru       1.00      0.99      1.00      4333
#           uz       1.00      0.99      0.99      4325
#
#     accuracy                           0.99     12907
#    macro avg       0.99      0.99      0.99     12907
# weighted avg       0.99      0.99      0.99     12907

# %%
def detect_language(text):
    text_tfidf = vectorizer.transform([text])
    lang = model.predict(text_tfidf)[0]
    return lang

# Example usage:
new_text = "объединить фрейм данных"
predicted_language = detect_language(new_text)
print(f"Detected language: {predicted_language}")
# Out:
# Detected language: ru

# %%
data.isnull().sum()
# Out:
# text    11
# lang     0
# dtype: int64

# %%
data = data.dropna()

# %%
import pickle

# Saving the model
with open('model.pkl', 'wb') as file:
    pickle.dump(model, file)

# Loading the model
with open('model.pkl', 'rb') as file:
    loaded_model = pickle.load(file)
